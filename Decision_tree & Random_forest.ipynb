# %% [markdown]
# # Decision Trees and Random Forests

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('kyphosis.csv')

# %%
df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
sns.pairplot(df,hue='Kyphosis',palette='Set2')

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Kyphosis',axis=1)
y = df['Kyphosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model1 = DecisionTreeClassifier()

# %%
model1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
modedl1_pred = dtree.predict(X_test)
model1.score(X_test,y_test)
# Out:
# 0.76

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,modedl1_pred))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.90      0.82      0.86        22
#      present       0.20      0.33      0.25         3
#
#     accuracy                           0.76        25
#    macro avg       0.55      0.58      0.55        25
# weighted avg       0.82      0.76      0.78        25

# %%
print(confusion_matrix(y_test,modedl1_pred))
# Out:
# [[18  4]
#  [ 2  1]]

# %%
from IPython.display import Image  
from six import StringIO
from sklearn.tree import export_graphviz
import pydot 

f = list(df.columns[1:])
f
# Out:
# ['Age', 'Number', 'Start']

# %%
dot = StringIO()  
export_graphviz(dtree, out_file=dot,feature_names=features,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot.getvalue())  
Image(graph[0].create_png())

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(n_estimators=100)
model2.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
model2_pred = model2.predict(X_test)
model2.score(X_test,y_test)
# Out:
# 0.76

# %%
print(confusion_matrix(y_test,model2_pred))
# Out:
# [[18  4]
#  [ 2  1]]

# %%
print(classification_report(y_test,model2_pred))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.90      0.82      0.86        22
#      present       0.20      0.33      0.25         3
#
#     accuracy                           0.76        25
#    macro avg       0.55      0.58      0.55        25
# weighted avg       0.82      0.76      0.78        25
